# %% [markdown]
# <a href="https://colab.research.google.com/github/ayaanaj26/chord-classifier/blob/main/chord_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ayaanaj26/mega.git
# Out:
# Cloning into 'mega'...
# remote: Enumerating objects: 490, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 490 (delta 39), reused 30 (delta 30), pack-reused 406
# Receiving objects: 100% (490/490), 5.45 MiB | 30.47 MiB/s, done.
# Resolving deltas: 100% (120/120), done.

# %%
# %%bash
# cd mega
# ls -a
# Out:
# .
# ..
# CODE_OF_CONDUCT.md
# CONTRIBUTING.md
# docs
# examples
# fairseq
# fairseq_cli
# .git
# .gitignore
# hubconf.py
# LICENSE
# pyproject.toml
# README.md
# scripts
# setup.py
# tests
# train.py

# %%
# !kaggle datasets download -d fabianavinci/guitar-chords-v2
# Out:
# ...
#  98% 713M/729M [00:10<00:00, 124MB/s]
# 100% 729M/729M [00:10<00:00, 73.3MB/s]

# %%
# !mkdir /root/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !mv kaggle.json /root/.kaggle

# %%
# !unzip guitar-chords-v2.zip
# Out:
# Archive:  guitar-chords-v2.zip
#   inflating: Test/Am/Am_AcousticGuitar_RodrigoMercador_1.wav
#   inflating: Test/Am/Am_AcousticGuitar_RodrigoMercador_2.wav
#   inflating: Test/Am/Am_AcousticGuitar_RodrigoMercador_3.wav
#   inflating: Test/Am/Am_AcousticGuitar_RodrigoMercador_4.wav
#   inflating: Test/Am/Am_AcusticVince_JO_1.wav
#   inflating: Test/Am/Am_AcusticVince_JO_2.wav
#   inflating: Test/Am/Am_AcusticVince_JO_3.wav
#   inflating: Test/Am/Am_AcusticVince_JO_4.wav
#   inflating: Test/Am/Am_Classic2_Carolina_1.wav
#   inflating: Test/Am/Am_Classic2_Carolina_2.wav
#   inflating: Test/Am/Am_Classic2_Carolina_3.wav
#   inflating: Test/Am/Am_Classic2_Carolina_4.wav
#   inflating: Test/Am/Am_Classic3_Carolina_1.wav
#   inflating: Test/Am/Am_Classic3_Carolina_2.wav
#   inflating: Test/Am/Am_Classic3_Carolina_3.wav
#   inflating: Test/Am/Am_Classic3_Carolina_4.wav
#   inflating: Test/Am/Am_ClassicVince_JO_1.wav
#   inflating: Test/Am/Am_ClassicVince_JO_2.wav
# ...

# %%
audiopath = "/content/Training/Am/Am_AcusticPlug16_2.wav"
# Out:
#   File "<ipython-input-9-1020b878e265>", line 1
#     audiopath = /content/Training/Am/Am_AcusticPlug16_2.wav
#                 ^
# SyntaxError: invalid syntax

# %%
# !cp /content/mega/fairseq/data/audio/speech_commands_dataset.py /content/mega/fairseq/data/audio/chord_classifier_dataset.py

# %%
dataset = SpeechCommandsDataset(
            partition="test",
            length=16000,  # self.L,
            mfcc=True,
            sr=1,
            dropped_rate=0.,
            path=self.args.data,
            all_classes=True,
        )
